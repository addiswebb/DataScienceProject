# %%
import pandas as pd
import numpy as np
import re
import requests

# %%
dataset_path = 'output/1000_downloaded_dataset.csv'
cleaned_dataset_path = 'output/1000_clean_dataset.csv'
total_occurrences_by_division_path = 'output/1000_total_occurrences_by_division.csv'
total_occurrences_by_county_year_path = 'output/1000_total_occurrennces_by_county_year.csv'

# %% [markdown]
# # Downloading the dataset
#
# The dataset we are using comes from the [Central Statistics Office of Ireland](cso.ie)
#
# The information we will be using from this dataset is:
# * `Year`
# * `County/Garda Station Division`
# * `Type of offence`
# * `Number of occurences`
#
# Aswell as the index of a crime relative to its garda station called `Crime Index`
#
# The dataset only includes countys from the **Republic of Ireland** and does not include *Northern Ireland*. `Cork` and `Dublin` are split up into seperate regions, north south etc, we can later combine these if neccessary. Some of the smaller countys are also grouped together like `Cavan/Monaghan`.

# %%
url = 'https://ws.cso.ie/public/api.restful/PxStat.Data.Cube_API.ReadDataset/CJA07/CSV/1.0/'
r = requests.get(url, allow_redirects=True)
open(dataset_path, 'wb').write(r.content)
print("Downloaded successfully at: "+dataset_path)
# Out:
# Downloaded successfully at: output/1000_downloaded_dataset.csv

# %% [markdown]
# # Cleaning the dataset
#
# We need to remove any columns that have useless data, aswell as rename some of the poorly named columns for better readability later on.
#
# Every cell in crime index gets subtracted by `3` to bring it into a more usable index range. *0-12 instead of 3-15*
#
# The final lambda changes the cells in `Garda Station` from `[Station ID] [Town], [County] Division` to `[County] Division`, since we will not be using the `[Town]` or `[Station ID]`

# %%
changes = {
    'Dublin':[
        'D.M.R. Western',
        'D.M.R. Eastern',
        'D.M.R. North Central',
        'D.M.R. Southern',
        'D.M.R. South Central',
        'D.M.R. Northern'
    ],
    'Cork':[
        'Cork City',
        'Cork West',
        'Cork North'
    ]
}

def clean_county(x):
    x = re.search('\s([^,]+$)',x).group(1).replace(' Division','')
    for new_county in changes:
        for old_county in changes[new_county]:
            x = x.replace(old_county,new_county)
    return x

# %%
dataset = pd.read_csv(dataset_path)
dataset = dataset.drop(columns=['STATISTIC', 'STATISTIC Label','UNIT','TLIST(A1)','C03037V03742'],axis=4)
dataset = dataset.rename(columns={'C02480V03003': 'Crime Index', 'VALUE': 'Occurrences'})
dataset['Crime Index'] = dataset['Crime Index'] - 3
dataset['Garda Station'] = dataset['Garda Station'].apply(clean_county)

# %%
dataset[dataset['Garda Station']=='Cavan/Monaghan']
# Out:
#         Year   Garda Station  Crime Index  \
# 336     2003  Cavan/Monaghan            0
# 337     2003  Cavan/Monaghan            1
# 338     2003  Cavan/Monaghan            2
# 339     2003  Cavan/Monaghan            3
# 340     2003  Cavan/Monaghan            4
# ...      ...             ...          ...
# 128467  2021  Cavan/Monaghan            7
# 128468  2021  Cavan/Monaghan            8
# 128469  2021  Cavan/Monaghan            9
# 128470  2021  Cavan/Monaghan           10
# 128471  2021  Cavan/Monaghan           12
#
#                                           Type of Offence  Occurrences
# 336     Attempts/threats to murder, assaults, harassme...            4
# 337                           Dangerous or negligent acts           10
# 338                       Kidnapping and related offences            0
# 339             Robbery, extortion and hijacking offences            0
# 340                         Burglary and related offences            4
# ...                                                   ...          ...
# 128467                           Controlled drug offences           16
# 128468                    Weapons and Explosives Offences            4
# 128469          Damage to property and to the environment           14
# 128470        Public order and other social code offences           18
# 128471  Offences against government, justice procedure...           18
#
# [5700 rows x 5 columns]

# %%
total_divisions = dataset['Garda Station'].nunique() - 7 + 5
total_divisions
# Out:
# 19

# %%
dataset['Garda Station'].unique()
# Out:
# array(['Limerick', 'Laois/Offaly', 'Waterford', 'Galway', 'Donegal',
#        'Kerry', 'Cork', 'Louth', 'Tipperary', 'Wicklow', 'Cavan/Monaghan',
#        'Meath', 'Roscommon/Longford', 'Westmeath', 'Kildare', 'Dublin',
#        'Mayo', 'Sligo/Leitrim', 'Kilkenny/Carlow', 'Wexford', 'Clare'],
#       dtype=object)

# %%
dataset = dataset.rename(columns={'Garda Station':'County'})
dataset
# Out:
#         Year    County  Crime Index  \
# 0       2003  Limerick            0
# 1       2003  Limerick            1
# 2       2003  Limerick            2
# 3       2003  Limerick            3
# 4       2003  Limerick            4
# ...      ...       ...          ...
# 128587  2021      Cork            7
# 128588  2021      Cork            8
# 128589  2021      Cork            9
# 128590  2021      Cork           10
# 128591  2021      Cork           12
#
#                                           Type of Offence  Occurrences
# 0       Attempts/threats to murder, assaults, harassme...           18
# 1                             Dangerous or negligent acts           14
# 2                         Kidnapping and related offences            0
# 3               Robbery, extortion and hijacking offences            0
# 4                           Burglary and related offences           27
# ...                                                   ...          ...
# 128587                           Controlled drug offences           40
# 128588                    Weapons and Explosives Offences            3
# 128589          Damage to property and to the environment           52
# 128590        Public order and other social code offences           64
# 128591  Offences against government, justice procedure...            8
#
# [128592 rows x 5 columns]

# %%
def split_county(x,i):
    match = re.search('(.+)\/(.+)',x['County'])
    if match:
        x['County'] = match.group(i)
        x['Occurrences'] = x['Occurrences']/2
        #new_df = pd.DataFrame({'Garda Station':[match.group(2)],'Occurrences':[int(x['Occurrences'])]})
        #sums = sums.merge(new_df, how='inner')
        #pd.concat([sums, pd.DataFrame([[match.group(2),x['Occurrences']]],columns=['Garda Station', 'Occurrences'])],ignore_index=True)
    return x

# %%
sums_by_year = dataset.groupby(by=['Year','County'])['Occurrences'].sum().drop(columns=['Crime Index'])
sums_by_year = sums_by_year.reset_index()
pairs = sums_by_year[sums_by_year['County'].str.contains('/')].copy()
pairs = pairs.apply(lambda x: split_county(x,2),axis=1)
sums_by_year = sums_by_year.apply(lambda x: split_county(x,1),axis=1)
sums_by_year = sums_by_year.merge(pairs,how='outer')
sums_by_year.head()
# Out:
#    Year   County  Occurrences
# 0  2003    Cavan       2581.0
# 1  2003    Clare       3826.0
# 2  2003     Cork      22321.0
# 3  2003  Donegal       7073.0
# 4  2003   Dublin      95528.0

# %%
sums = dataset.groupby(by='County')['Occurrences'].sum()
sums = sums.to_frame().reset_index()
sums.head()
pairs = sums[sums['County'].str.contains('/')].copy()
pairs = pairs.apply(lambda x: split_county(x,2),axis=1)
sums = sums.apply(lambda x: split_county(x,1),axis=1)
sums = sums.merge(pairs,how='outer')
sums.head()
# Out:
#     County  Occurrences
# 0    Cavan      51026.0
# 1    Clare      78677.0
# 2     Cork     418178.0
# 3  Donegal     114465.0
# 4   Dublin    1862658.0

# %%
dataset.head()
# Out:
#    Year    County  Crime Index  \
# 0  2003  Limerick            0
# 1  2003  Limerick            1
# 2  2003  Limerick            2
# 3  2003  Limerick            3
# 4  2003  Limerick            4
#
#                                      Type of Offence  Occurrences
# 0  Attempts/threats to murder, assaults, harassme...           18
# 1                        Dangerous or negligent acts           14
# 2                    Kidnapping and related offences            0
# 3          Robbery, extortion and hijacking offences            0
# 4                      Burglary and related offences           27

# %%
dataset.to_csv(cleaned_dataset_path,index=False)
sums.to_csv(total_occurrences_by_division_path,index=False)
sums_by_year.to_csv(total_occurrences_by_county_year_path,index=False)
print("Saved all datasets")
# Out:
# Saved all datasets
